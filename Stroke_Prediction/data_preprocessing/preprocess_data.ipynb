# %%
#This script processes your raw data by filling in missing values, removing any data anomalies, and normalizing the data (making sure it has a consistent scale). It also splits the data into training, validation, and test sets.

# %% [markdown]
# # Dropping:
#
# * Dropping of Smoking_status label can be decided. Let us not drop it at first. id drop
#
# # Label Encoding:
#
# * Convert categorical labels to numerical format using LabelEncoder.
#
# #Splitting Data:
#
# * Split the dataset into train, test, and valid sets using train_test_split. Ensure to stratify if the classes are imbalanced to maintain class proportions in each split.
#
# # Normalization:
#
# * Apply normalization (e.g., using StandardScaler) to the train set and then transform the test and valid sets using the same scaler to prevent data leakage.
#
# # Applying SMOTE:
#
# * Apply SMOTE to the normalized train set to oversample the minority class. Do not apply SMOTE to test and valid sets

# %%
from google.colab import drive
import pandas as pd
import os
from imblearn.over_sampling import SMOTE
import numpy as np

# %%
drive.mount('/content/drive' , force_remount=True)
project_path = '/content/drive/MyDrive/Stroke_Prediction/data_preprocessing/raw_data.csv'

dataset = pd.read_csv(project_path)
dataset = pd.DataFrame(dataset)
dataset.head()
# Out:
# Mounted at /content/drive
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status
# ...

# %%
#@title Splitting data into Test, Valid and Train.

# %%
#@title Normalization and saving parameters

# %%
#@title Random Oversampling

#Need to encode the labels for before applying SMOTE. So, label encoding need to be done before.
# Undersampler = SMOTE(sampling_strategy='minority')
# X_resampled, y_resampled = Undersampler.fit_resample(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-44a7953eb38b> in <cell line: 3>()
#       1 #@title Random Oversampling
#       2 Undersampler = SMOTE(sampling_strategy='minority')
# ----> 3 X_resampled, y_resampled = Undersampler.fit_resample(X, y)
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      80         check_classification_targets(y)
#      81         arrays_transformer = ArraysTransformer(X, y)
# ---> 82         X, y, binarize_y = self._check_X_y(X, y)
#      83
#      84         self.sampling_strategy_ = check_sampling_strategy(
#
# ...
